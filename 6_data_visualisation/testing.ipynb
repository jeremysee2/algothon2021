# %%
import pandas as pd
import numpy as np
df = pd.read_csv("V4P0R_data_cleaning.csv")
df.head
# Out:
#             Price
# 0     2397.167568
# 1     2371.333300
# 2     2573.025408
# 3     2574.872476
# 4     1769.398592
# ...           ...
# 1204  1498.033146
# 1205   527.306705
# 1206   326.861945
# 1207   373.015675
# 1208   253.373565
#
# [1209 rows x 1 columns]

# %%
df2 = pd.read_csv("COVID-19-geographic-disbtribution-worldwide-2020-03-29.csv")
dff = df2.groupby('countriesAndTerritories', as_index=False)[['deaths','cases']].sum()
df2.to_dict('records')
# Out:
# 020',
#   'day': 24,
#   'month': 3,
#   'year': 2020,
#   'cases': 3,
#   'deaths': 0,
#   'countriesAndTerritories': 'Benin',
#   'geoId': 'BJ',
#   'countryterritoryCode': 'BEN',
#   'popData2018': 11485048.0},
#  {'dateRep': '3/23/2020',
#   'day': 23,
#   'month': 3,
#   'year': 2020,
#   'cases': 0,
#   'deaths': 0,
#   'countriesAndTerritories': 'Benin',
#   'geoId': 'BJ',
#   'countryterritoryCode': 'BEN',
#   'popData2018': 11485048.0},
#  {'dateRep': '3/22/2020',
#   'day': 22,
#   'month': 3,
#   'year': 2020,
#   'cases': 0,
#   'deaths': 0,
#   'countriesAndTerritories': 'Benin',
#   'geoId': 'BJ',
#   'countryterritoryCode': 'BEN',
#   'popData2018': 11485048.0},
#  {'dateRep': '3/21/2020',
#   'day': 21,
#   'month': 3,
#   'year': 2020,
#   'cases': 0,
#   'deaths': 0,
#   'countriesAndTerritories': 'Benin',
#   'geoId': 'BJ',
#   'countryterritoryCode': 'BEN',
#   'popData2018': 11485048.0},
#  {'dateRep': '3/20/2020',
#   'day': 20,
#   'month': 3,
# ...
